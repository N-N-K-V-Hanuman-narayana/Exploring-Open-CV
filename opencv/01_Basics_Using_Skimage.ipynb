# %%
# !pip install scikit-image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-image in C:\Users\HANUMAN NARAYANA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (0.26.0)
# Requirement already satisfied: numpy>=1.24 in C:\Users\HANUMAN NARAYANA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-image) (2.4.6)
# Requirement already satisfied: scipy>=1.11.4 in C:\Users\HANUMAN NARAYANA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-image) (1.17.1)
# Requirement already satisfied: networkx>=3.0 in C:\Users\HANUMAN NARAYANA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in C:\Users\HANUMAN NARAYANA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-image) (12.2.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in C:\Users\HANUMAN NARAYANA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-image) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in C:\Users\HANUMAN NARAYANA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-image) (2026.6.1)
# Requirement already satisfied: packaging>=21 in C:\Users\HANUMAN NARAYANA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-image) (26.2)
# Requirement already satisfied: lazy-loader>=0.4 in C:\Users\HANUMAN NARAYANA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-image) (0.5)

# %%
from skimage import io 
img = io.imread('mani2.jpg') 
io.imshow(img)
# Out:
# C:\Users\HANUMAN NARAYANA\AppData\Local\Temp\ipykernel_23592\324622164.py:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img)

# %%
from skimage import io

# Read image
img = io.imread("mani2.jpg")

# Print image dimensions
print("Image Shape:", img.shape)
# Out:
# Image Shape: (1280, 863, 3)

# %%
from skimage import io

img = io.imread("mani2.jpg")

height = img.shape[0]
width = img.shape[1]
channels = img.shape[2]

print("Height =", height)
print("Width =", width)
print("Channels =", channels)
# Out:
# Height = 1280
# Width = 863
# Channels = 3

# %%
from skimage import io

img = io.imread("mani2.jpg")

print("Data Type:", img.dtype)
# Out:
# Data Type: uint8

# %%
from skimage import io

img = io.imread("mani2.jpg")

# Pixel at row 100, column 100
print(img[100,100])
# Out:
# [154 103 100]

# %%
from skimage import io

img = io.imread("mani2.jpg")

print("Total Pixels =", img.size)
# Out:
# Total Pixels = 3313920

# %%
from skimage import io
import matplotlib.pyplot as plt

img = io.imread("mani2.jpg")

plt.imshow(img)
plt.title("Original Image")
plt.show()

# %%
from skimage import io

img = io.imread("mani2.jpg")

# Crop region
crop = img[100:400, 100:400]

io.imshow(crop)
io.show()
# Out:
# C:\Users\HANUMAN NARAYANA\AppData\Local\Temp\ipykernel_23592\2623073980.py:8: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(crop)
# C:\Users\HANUMAN NARAYANA\AppData\Local\Temp\ipykernel_23592\2623073980.py:9: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io

img = io.imread("mani2.jpg")

red = img[:,:,0]

io.imshow(red)
io.show()
# Out:
# C:\Users\HANUMAN NARAYANA\AppData\Local\Temp\ipykernel_23592\3911525008.py:7: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(red)
# C:\Users\HANUMAN NARAYANA\AppData\Local\Temp\ipykernel_23592\3911525008.py:8: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io

img = io.imread("mani2.j")

green = img[:,:,1]

io.imshow(green)
io.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[58], line 3
#       1 from skimage import io
#       2
# ----> 3 img = io.imread("wallp.png")
#       4
#       5 green = img[:,:,1]
#       6
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\skimage\_shared\utils.py:386, in deprecate_parameter.__call__.<locals>.fixed_func(*args, **kwargs)
#     382     elif self.new_name is not None:
#     383         # Assign old value to new one
#     384         kwargs[self.new_name] = deprecated_value
# --> 386 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\skimage\io\_io.py:82, in imread(fname, as_gray, plugin, **plugin_args)
#      79         plugin = 'tifffile'
#      81 with file_or_url_context(fname) as fname, _hide_plugin_deprecation_warnings():
# ---> 82     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      84 if not hasattr(img, 'ndim'):
#      85     return img
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\skimage\_shared\utils.py:690, in deprecate_func.__call__.<locals>.wrapped(*args, **kwargs)
#     684 stacklevel = (
#     685     self.stacklevel
#     686     if self.stacklevel is not None
#     687     else _warning_stacklevel(func)
#     688 )
#     689 warnings.warn(message, category=FutureWarning, stacklevel=stacklevel)
# --> 690 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\skimage\io\manage_plugins.py:254, in call_plugin(kind, *args, **kwargs)
#     251     except IndexError:
#     252         raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
# --> 254 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\skimage\io\_plugins\imageio_plugin.py:11, in imread(*args, **kwargs)
#       9 @wraps(imageio_imread)
#      10 def imread(*args, **kwargs):
# ---> 11     out = np.asarray(imageio_imread(*args, **kwargs))
#      12     if not out.flags['WRITEABLE']:
#      13         out = out.copy()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\imageio\v3.py:53, in imread(uri, index, plugin, extension, format_hint, **kwargs)
#      50 if index is not None:
#      51     call_kwargs["index"] = index
# ---> 53 with imopen(uri, "r", **plugin_kwargs) as img_file:
#      54     return np.asarray(img_file.read(**call_kwargs))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\imageio\core\imopen.py:113, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111     request.format_hint = format_hint
#     112 else:
# --> 113     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     115 source = "<bytes>" if isinstance(uri, bytes) else uri
#     117 # fast-path based on plugin
#     118 # (except in legacy mode)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\imageio\core\request.py:250, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     247     raise ValueError(f"Invalid Request.Mode: {mode}")
#     249 # Parse what was given
# --> 250 self._parse_uri(uri)
#     252 # Set extension
#     253 if extension is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\imageio\core\request.py:410, in Request._parse_uri(self, uri)
#     407 if is_read_request:
#     408     # Reading: check that the file exists (but is allowed a dir)
#     409     if not os.path.exists(fn):
# --> 410         raise FileNotFoundError("No such file: '%s'" % fn)
#     411 else:
#     412     # Writing: check that the directory to write to does exist
#     413     dn = os.path.dirname(fn)
#
# FileNotFoundError: No such file: 'C:\Users\HANUMAN NARAYANA\OneDrive\Apps\Desktop\wallp.png'
