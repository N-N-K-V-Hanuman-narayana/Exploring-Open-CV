# %%
# Bilateral Filter

import cv2
import matplotlib.pyplot as plt

img = cv2.imread("mai")

bilateral = cv2.bilateralFilter(img, 9, 75, 75)

bilateral = cv2.cvtColor(bilateral, cv2.COLOR_BGR2RGB)
plt.imshow(bilateral)
plt.title("Bilateral Filter")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[12], line 8
#       4 import matplotlib.pyplot as plt
#       5
#       6 img = cv2.imread("wallp.png")
#       7
# ----> 8 bilateral = cv2.bilateralFilter(img, 9, 75, 75)
#       9
#      10 bilateral = cv2.cvtColor(bilateral, cv2.COLOR_BGR2RGB)
#      11 plt.imshow(bilateral)
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\bilateral_filter.dispatch.cpp:448: error: (-215:Assertion failed) !_src.empty() in function 'cv::bilateralFilter'
